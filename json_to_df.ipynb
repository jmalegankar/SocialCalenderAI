# %%
import pandas as pd
import json

# %%
dfs = []

# %%
with open("cleaned_json/extracted_bars.json", 'r') as f:
    data = json.load(f)
    df = pd.json_normalize(data)
    df['properties.catering.cuisine'].fillna('alcohol', inplace=True)
    dfs.append(df)
df.head()
# Out:
# /var/folders/lj/tq8n9nnj1hxgf9rws0syb25m0000gn/T/ipykernel_4856/935021893.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['properties.catering.cuisine'].fillna('alcohol', inplace=True)
#       type                      properties.name properties.country  \
# 0  Feature                Rabbit's Foot Meadery      United States
# 1  Feature                          Pizza Depot      United States
# 2  Feature            Fuego Sports Bar and Club      United States
# ...

# %%
with open("cleaned_json/extracted_restaurant.json", 'r') as f:
    data = json.load(f)
    df = pd.json_normalize(data)
    dfs.append(df)
df.head()
# Out:
#       type                 properties.name properties.country  \
# 0  Feature        Saint John’s Bar & Grill      United States
# 1  Feature  Gumba's Italian Foods Pizzaria      United States
# 2  Feature                      Seto Ramen      United States
# 3  Feature                           Lados      United States
# 4  Feature                     Madras Café      United States
#
#   properties.country_code properties.state   properties.county  \
# 0                      us       California  Santa Clara County
# 1                      us       California  Santa Clara County
# 2                      us       California  Santa Clara County
# 3                      us       California  Santa Clara County
# 4                      us       California  Santa Clara County
#
#   properties.city properties.postcode    properties.street  \
# 0       Sunnyvale               94085  Lawrence Expressway
# 1       Sunnyvale               94086  South Murphy Avenue
# ...

# %%
with open("cleaned_json/extracted_fast_food.json", 'r') as f:
    data = json.load(f)
    df = pd.json_normalize(data)
    dfs.append(df)
df.head()
# Out:
#       type          properties.name properties.country  \
# 0  Feature               Sweetgreen      United States
# 1  Feature                Five Guys      United States
# 2  Feature      A Slice of New York      United States
# 3  Feature  Ike's Love & Sandwiches      United States
# 4  Feature                      KFC      United States
#
#   properties.country_code properties.state   properties.county  \
# 0                      us       California  Santa Clara County
# 1                      us       California  Santa Clara County
# 2                      us       California  Santa Clara County
# 3                      us       California  Santa Clara County
# 4                      us       California  Santa Clara County
#
#   properties.city properties.postcode    properties.street  \
# 0       Sunnyvale               94087  West El Camino Real
# 1       Sunnyvale               94085  East El Camino Real
# 2       Sunnyvale               94086  West El Camino Real
# ...

# %%
with open("cleaned_json/extracted_cafes.json", 'r') as f:
    data = json.load(f)
    df = pd.json_normalize(data)
    dfs.append(df)
df.head()
# Out:
#       type      properties.name properties.country properties.country_code  \
# 0  Feature            Starbucks      United States                      us
# 1  Feature  Von’s Express Halal      United States                      us
# 2  Feature       Paris Baguette      United States                      us
# 3  Feature            Starbucks      United States                      us
# 4  Feature     Bagel Place Cafe      United States                      us
#
#   properties.state   properties.county properties.city properties.postcode  \
# 0       California  Santa Clara County       Sunnyvale               94087
# 1       California  Santa Clara County       Sunnyvale               94085
# 2       California  Santa Clara County       Sunnyvale               94087
# 3       California  Santa Clara County       Sunnyvale               94087
# 4       California  Santa Clara County       Sunnyvale               94085
#
#      properties.street properties.housenumber  ...  \
# ...

# %%
len(dfs)
# Out:
# 4

# %%
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df['id'] = combined_df.index + 1

# %%
df.to_csv('restaurants.csv')

# %%
# !pip3 install llama-index
# !pip3 install llama-index-vector-stores-mongodb
# !pip3 install llama-index-embeddings-openai
# !pip3 install pymongo
# !pip3 install datasets
# !pip3 install pandas
# !pip3 install --upgrade openai
# !pip3 install matplotlib

# %%
import pandas as pd
from llama_index.core.settings import Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
import json
from llama_index.core import Document
from llama_index.core.schema import MetadataMode
from llama_index.core.node_parser import SentenceSplitter
import pymongo
from llama_index.vector_stores.mongodb import MongoDBAtlasVectorSearch
from llama_index.core import VectorStoreIndex, StorageContext
import pprint
from llama_index.core.response.notebook_utils import display_response
from dotenv import dotenv_values


config = dotenv_values(".env")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 from llama_index.core.settings import Settings
#       3 from llama_index.llms.openai import OpenAI
#       4 from llama_index.embeddings.openai import OpenAIEmbedding
#
# ModuleNotFoundError: No module named 'llama_index'

# %%
# %env OPENAI_API_KEY=sk-proj-DmGRWGw6WeTUaBtnmiRYT3BlbkFJEyEy34zGByNm4Y9kMvyA
# Out:
# env: OPENAI_API_KEY=sk-proj-DmGRWGw6WeTUaBtnmiRYT3BlbkFJEyEy34zGByNm4Y9kMvyA

# %%
#LLM is default OpenAI-3.5Turbo for end analysis of results, While embeddingf is text-3-small model
def LLMandEmbeddingModel(llm=None,embeddingmodel="text-embedding-3-small"):
    #Embedding Model - outputs 256 dimensions of vector
    embed_model = OpenAIEmbedding(model=embeddingmodel, dimensions=256)

    #Here's where we keep our Input Custom LLM
    if llm:
        Settings.llm = llm
    else: #default
        llm = OpenAI()
        Settings.llm = llm

    #we use Standard open-ai text-embedding-3-small - Can improve this....Check future improvements cell
    Settings.embed_model = embed_model
    
    return embed_model
embeddingmodel = LLMandEmbeddingModel()

# %%
#Embed data in form of LLAMA Documents, Select important features in metadata for llm to use while text feature is what you represent that point in n-dimensional space
def LLAMAindexdocs(inputdata,metadata,label):
    #Only extracting important features
    inputdata = inputdata[metadata]
    # Convert the DataFrame to a JSON string representation
    input_json = inputdata.to_json(orient='records')
    # Load the JSON string into a Python list of dictionaries
    documents_list = json.loads(input_json)

    finaldocs = []

    for document in documents_list:
        # Value for metadata must be one of (str, int, float, None)
        for column in metadata:
            document[column] = json.dumps(document[column])

        finalabel = ''
        for str in label:
            finalabel=finalabel+'-'+document[str]
        # Create a Document object with the text and excluded metadata for llm and embedding models
        llama_document = Document(
            text=finalabel,
            metadata=document,
            excluded_llm_metadata_keys=label, #Exclude columns for creating semantic meaning - ignoring cuisine since its already passed in text
            excluded_embed_metadata_keys=label,
            metadata_template="{key}=>{value}",
            text_template="Metadata: {metadata_str}\n-----\nContent: {content}",
            )

        finaldocs.append(llama_document)

    return finaldocs

llama_documents = LLAMAindexdocs(inputdata=combined_df,metadata=["properties.name","id","properties.catering.cuisine"],label=["properties.name","id"])

# %%
#Embed data in form of LLAMA Documents, Select important features in metadata for llm to use while text feature is what you represent that point in n-dimensional space
def LLAMAindexdocs(inputdata,metadata,label):
    #Only extracting important features
    inputdata = inputdata[metadata]
    # Convert the DataFrame to a JSON string representation
    input_json = inputdata.to_json(orient='records')
    # Load the JSON string into a Python list of dictionaries
    documents_list = json.loads(input_json)

    finaldocs = []

    for document in documents_list:
        # Value for metadata must be one of (str, int, float, None)
        for column in metadata:
            document[column] = json.dumps(document[column])

        finalabel = ''
        for str in label:
            finalabel=finalabel+'-'+document[str]
        # Create a Document object with the text and excluded metadata for llm and embedding models
        llama_document = Document(
            text=finalabel,
            metadata=document,
            excluded_llm_metadata_keys=label, #Exclude columns for creating semantic meaning - ignoring cuisine since its already passed in text
            excluded_embed_metadata_keys=label,
            metadata_template="{key}=>{value}",
            text_template="Metadata: {metadata_str}\n-----\nContent: {content}",
            )

        finaldocs.append(llama_document)

    return finaldocs
new_df = pd.read_csv('inputdatatoJAI/events_data.csv')
llama_documents_events = LLAMAindexdocs(inputdata=new_df,metadata=["title","event_id","description"],label=["title","event_id"])

# %%
# Observing an example of what the LLM and Embedding model receive as input
print(
    "\nThe LLM sees this: \n",
    llama_documents[2].get_content(metadata_mode=MetadataMode.LLM),
)
print(
    "\nThe Embedding model sees this: \n",
    llama_documents[2].get_content(metadata_mode=MetadataMode.EMBED),
)
llama_documents[2]
# Out:
# The LLM sees this:
#  Metadata: properties.catering.cuisine=>"ramen"
# -----
# Content: -"Seto Ramen"-3
#
# The Embedding model sees this:
#  Metadata: properties.catering.cuisine=>"ramen"
# -----
# Content: -"Seto Ramen"-3
# Document(id_='7fe79dc9-50ce-46a5-bcb1-d042c1eb248f', embedding=None, metadata={'properties.name': '"Seto Ramen"', 'id': '3', 'properties.catering.cuisine': '"ramen"'}, excluded_embed_metadata_keys=['properties.name', 'id'], excluded_llm_metadata_keys=['properties.name', 'id'], relationships={}, text='-"Seto Ramen"-3', start_char_idx=None, end_char_idx=None, text_template='Metadata: {metadata_str}\n-----\nContent: {content}', metadata_template='{key}=>{value}', metadata_seperator='\n')

# %%
# Observing an example of what the LLM and Embedding model receive as input
print(
    "\nThe LLM sees this: \n",
    llama_documents_events[2].get_content(metadata_mode=MetadataMode.LLM),
)
print(
    "\nThe Embedding model sees this: \n",
    llama_documents_events[2].get_content(metadata_mode=MetadataMode.EMBED),
)
llama_documents_events[2]
# Out:
# The LLM sees this:
#  Metadata: description=>"Cousins Arturo Villa and Cristian Valenzuela began playing at 10 years old in Culiacan, Sinaloa. Together with members Gil Lizarraga & Jesus Alan Obeso they formed the Musica Mexicana band Edici\u00f3n..."
# -----
# Content: -"Edici\u00f3n Especial \u2013 Segunda Edici\u00f3n Tour"-2
#
# The Embedding model sees this:
#  Metadata: description=>"Cousins Arturo Villa and Cristian Valenzuela began playing at 10 years old in Culiacan, Sinaloa. Together with members Gil Lizarraga & Jesus Alan Obeso they formed the Musica Mexicana band Edici\u00f3n..."
# -----
# Content: -"Edici\u00f3n Especial \u2013 Segunda Edici\u00f3n Tour"-2
# ...

# %%
#Embedding the documents - Don't use function....if terminates due to low credits already processed data may not return
parser = SentenceSplitter()
nodes = parser.get_nodes_from_documents(llama_documents)

for node in nodes:
    node_embedding = embeddingmodel.get_text_embedding(
        node.get_content(metadata_mode=MetadataMode.EMBED)
    )
    node.embedding = node_embedding
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 6
#       3 nodes = parser.get_nodes_from_documents(llama_documents_events)
#       5 for node in nodes:
# ----> 6     node_embedding = embeddingmodel.get_text_embedding(
#       7         node.get_content(metadata_mode=MetadataMode.EMBED)
#       8     )
#       9     node.embedding = node_embedding
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/llama_index/core/instrumentation/dispatcher.py:230, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     226 self.span_enter(
#     227     id_=id_, bound_args=bound_args, instance=instance, parent_id=parent_id
#     228 )
#     229 try:
# --> 230     result = func(*args, **kwargs)
#     231 except BaseException as e:
#     232     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# ...

# %%
#Embedding the documents - Don't use function....if terminates due to low credits already processed data may not return
parser = SentenceSplitter()
event_nodes = parser.get_nodes_from_documents(llama_documents_events)

for node in event_nodes:
    node_embedding = embeddingmodel.get_text_embedding(
        node.get_content(metadata_mode=MetadataMode.EMBED)
    )
    node.embedding = node_embedding

# %%
import pickle
with open('event_nodes.pkl', 'wb') as f:
    pickle.dump(nodes, f)

# %%
#Data Ingestion into Vector DB
def ConnectDBandIngestData(dburi,username,password,dbname,table,inputdata,type):
  if not dburi:
    return "MONGO_URI not set in environment variables"
  dburi = dburi.replace('<username>',username)
  dburi = dburi.replace('<password>',password)

  def get_mongo_client(dburi):
    """Establish connection to the MongoDB."""
    try:
      client = pymongo.MongoClient(dburi)
      print("Connection to MongoDB successful")
      return client
    except pymongo.errors.ConnectionFailure as e:
      print(f"Connection failed: {e}")
      return None
    
  mongo_client = get_mongo_client(dburi)

  db = mongo_client[dbname]
  collection = db[table]

  if type=='startfresh':
    # To ensure we are working with a fresh collection
    # delete any existing records in the collection
    collection.delete_many({})
  elif type=='update':
    existing_data = set(item['text'] for item in collection.find({}, {'text': 1})) 

    new_data = [item for item in inputdata if item['text'] not in existing_data] 
        
    if new_data:
      vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name=dbname, collection_name=table, index_name="restaurantvectorindex")
      vector_store.add(new_data)
      return vector_store
    else:
      print("No new data to add")
      vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name=dbname, collection_name=table, index_name="restaurantvectorindex")
      return vector_store

  #Ingest
  vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name=dbname, collection_name=table, index_name="restaurantvectorindex")
  vector_store.add(inputdata)
  return vector_store

vector_store = ConnectDBandIngestData(dburi='mongodb+srv://<username>:<password>@socialcalenderai.qimcftw.mongodb.net/?retryWrites=true&w=majority&appName=SocialCalenderAI',
                       username='pchitturi',
                       password='Obbxi5bBdy08TJfl',
                       dbname='SocialCalenderDB',
                       table='Restaurants',
                       inputdata=nodes,
                       type='startfresh') #Don't use update type, not tested yet
# Out:
# Connection to MongoDB successful
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[44], line 46
#      43   vector_store.add(inputdata)
#      44   return vector_store
# ---> 46 vector_store = ConnectDBandIngestData(dburi='mongodb+srv://<username>:<password>@socialcalenderai.qimcftw.mongodb.net/?retryWrites=true&w=majority&appName=SocialCalenderAI',
#      47                        username='pchitturi',
#      48                        password='Obbxi5bBdy08TJfl',
#      49                        dbname='SocialCalenderDB',
#      50                        table='Restaurants',
#      51                        inputdata=nodes,
#      52                        type='startfresh') #Don't use update type, not tested yet
#
# Cell In[44], line 26, in ConnectDBandIngestData(dburi, username, password, dbname, table, inputdata, type)
#      21 collection = db[table]
# ...

# %%
#Data Ingestion into Vector DB
def ConnectDBandIngestData(dburi,username,password,dbname,table,inputdata,type):
  if not dburi:
    return "MONGO_URI not set in environment variables"
  dburi = dburi.replace('<username>',username)
  dburi = dburi.replace('<password>',password)

  def get_mongo_client(dburi):
    """Establish connection to the MongoDB."""
    try:
      client = pymongo.MongoClient(dburi)
      print("Connection to MongoDB successful")
      return client
    except pymongo.errors.ConnectionFailure as e:
      print(f"Connection failed: {e}")
      return None
    
  mongo_client = get_mongo_client(dburi)

  db = mongo_client[dbname]
  collection = db[table]

  if type=='startfresh':
    # To ensure we are working with a fresh collection
    # delete any existing records in the collection
    collection.delete_many({})
  elif type=='update':
    existing_data = set(item['text'] for item in collection.find({}, {'text': 1})) 

    new_data = [item for item in inputdata if item['text'] not in existing_data] 
        
    if new_data:
      vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name=dbname, collection_name=table, index_name="restaurantvectorindex")
      vector_store.add(new_data)
      return vector_store
    else:
      print("No new data to add")
      vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name=dbname, collection_name=table, index_name="restaurantvectorindex")
      return vector_store

  #Ingest
  vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name=dbname, collection_name=table, index_name="restaurantvectorindex")
  vector_store.add(inputdata)
  return vector_store

vector_store = ConnectDBandIngestData(dburi='mongodb+srv://<username>:<password>@socialcalenderai.qimcftw.mongodb.net/?retryWrites=true&w=majority&appName=SocialCalenderAI',
                       username='pchitturi',
                       password='Obbxi5bBdy08TJfl',
                       dbname='SocialCalenderDB',
                       table='EventsVectorDB',
                       inputdata=event_nodes,
                       type='startfresh') #Don't use update type, not tested yet

# %%
def get_mongo_client(dburi):
    """Establish connection to the MongoDB."""
    try:
      client = pymongo.MongoClient(dburi)
      print("Connection to MongoDB successful")
      return client
    except pymongo.errors.ConnectionFailure as e:
      print(f"Connection failed: {e}")
      return None

mongo_client = get_mongo_client("mongodb+srv://pchitturi:Obbxi5bBdy08TJfl@socialcalenderai.qimcftw.mongodb.net/?retryWrites=true&w=majority&appName=SocialCalenderAI")
vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name='SocialCalenderDB', collection_name='RestaurantsVectorDB', index_name="restaurantvectorindex")

#Test data embedding in Vector DB with OpenAI-3.5-turbo
index = VectorStoreIndex.from_vector_store(vector_store)

#Filter top k results from db....internal cosine similarity
query_engine = index.as_query_engine(similarity_top_k=3)

query = "I want have just vada pav"

response = query_engine.query(query)
display_response(response)
pprint.pprint(response.source_nodes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4, in get_mongo_client(dburi)
#       3 try:
# ----> 4   client = pymongo.MongoClient(dburi)
#       5   print("Connection to MongoDB successful")
#
# NameError: name 'pymongo' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8       print(f"Connection failed: {e}")
#       9       return None
# ---> 11 mongo_client = get_mongo_client("mongodb+srv://pchitturi:Obbxi5bBdy08TJfl@socialcalenderai.qimcftw.mongodb.net/?retryWrites=true&w=majority&appName=SocialCalenderAI")
#      12 vector_store = MongoDBAtlasVectorSearch(mongo_client, db_name='SocialCalenderDB', collection_name='RestaurantsVectorDB', index_name="restaurantvectorindex")
# ...
